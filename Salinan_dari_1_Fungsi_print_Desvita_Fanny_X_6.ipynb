# %% [markdown]
# <a href="https://colab.research.google.com/github/desfitafannyy/KKA-X-Semester-1/blob/main/Salinan_dari_1_Fungsi_print_Desvita_Fanny_X_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Nama: Desvita fanny Azalia putri\nKelas: X.6\nNo. Absen: 29")
# Out:
# Nama: Desvita fanny Azalia putri
# Kelas: X.6
# No. Absen: 29

# %% [markdown]
# Menampilkan Teks Bebas (String)

# %%
print("halo dunia")
# Out:
# halo dunia

# %%
print ("Nama: " + Nama)
# Out:
# Nama: Desvita Fanny Azalia P

# %%
print("""hari ini saya belajar phyton""")
# Out:
# hari ini saya belajar phyton

# %%
Warna = "biru"
Berat_badan=45

print(Warna)
print(Berat_badan)
# Out:
# biru
# 45

# %%
print("Bu Shinta berkata, \"Tolong perhatikan ke layar TV!\".")
# Out:
# Bu Shinta berkata, "Tolong perhatikan ke layar TV!".

# %%
print('Bu Shinta berkata, "Tolong perhatikan ke layar TV!".')
# Out:
# Bu Shinta berkata, "Tolong perhatikan ke layar TV!".

# %%
print("Nama: Ja\'far Shodiq\nKelas\t\t: X.6\nNo. Absen\t: 6")
# Out:
# Nama: Ja'far Shodiq
# Kelas		: X.6
# No. Absen	: 6

# %%
print('Nama\t\t: Ja\'faf Shodiq\nKelas\t\t: X.6\nNo. Absen\t: 6')
# Out:
# Nama		: Ja'faf Shodiq
# Kelas		: X.6
# No. Absen	: 6

# %%
print("Lokasi file tugas KKA: C:\\KKA\\Tugas Desvita")
# Out:
# Lokasi file tugas KKA: C:\KKA\Tugas Desvita

# %%
print("Nama\t\t: Desvita fanny Azalia putri\nkelas\t\t: X.6\nNo. Absen\t: 6")
# Out:
# Nama		: Desvita fanny Azalia putri
# kelas		: X.6
# No. Absen	: 6

# %%
print('Lokasi file tugas KKA: C:\\KKA\\Tugas Desvita fanny Azalia Putri\nkelas\t\t: X.6\nNo. Absen\t: 6')
# Out:
# Lokasi file tugas KKA: C:\KKA\Tugas Desvita fanny Azalia Putri
# kelas		: X.6
# No. Absen	: 6

# %%
Nama = "Desvita Fanny Azalia P"
usia = 14

print(Nama)
print(usia)
# Out:
# Desvita Fanny Azalia P
# 14

# %%
print ("Berat_badan: " + str(Berat_badan))
# Out:
# Berat_badan: 45

# %% [markdown]
# Parameter Fungsi print

# %%
tahun=2010
bulan= "Desember"
tanggal=14

print(tahun, end="-")
print(bulan, end="-")
print(tanggal)
# Out:
# 2010-Desember-14

# %%
print(tanggal, end="/")
print(bulan, end="/")
print(tahun)
# Out:
# 14/Februari/2010

# %%
nama_siswa_1 = "Fida"
nama_siswa_2 = "Ajik"
nama_siswa_3 = "Hadziq"

print(nama_siswa_1, end="~")
print(nama_siswa_2, end="~")
print(nama_siswa_3)
# Out:
# Fida~Ajik~Hadziq

# %%
print(nama_siswa_1, nama_siswa_2, nama_siswa_3, sep="~")
# Out:
# Fida~Ajik~Hadziq

# %%
print(nama_siswa_1, nama_siswa_2, nama_siswa_3, sep="-")
# Out:
# Fida-Ajik-Hadziq
